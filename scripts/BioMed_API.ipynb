# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from pymongo import MongoClient
import os

# %%
# Calculate the date for one week ago
one_week_ago = datetime.now() - timedelta(weeks=100)
formatted_date = one_week_ago.strftime("%Y-%m-%d")

# Define the API endpoint URL with a date filter
api_url = f"http://api.springernature.com/meta/v2/json?q=date:{formatted_date}&api_key=cb292c878bc13f005179f8c437c73a56"

# Make a GET request to the API
response = requests.get(api_url)

# Check if the request was successful
if response.status_code == 200:
    # Parse JSON response
    json_data = response.json()
    
    # Extract records
    records = json_data.get("records", [])
    
    # Convert records to DataFrame
    df = pd.DataFrame(records)

else:
    print("Error:", response.status_code)
    
df
# Out:
#   contentType                      identifier language  \
# 0     Article  doi:10.1007/s12046-022-01818-1       en
# 1     Article  doi:10.1186/s12874-022-01567-z       en
# 2     Article  doi:10.1007/s42979-022-01113-0       en
# 3     Article  doi:10.1007/s40430-022-03458-2       en
# 4     Article  doi:10.1186/s12944-022-01645-7       en
# 5     Article  doi:10.1007/s12046-021-01802-1       en
# 6     Article  doi:10.1186/s12944-022-01647-5       en
# 7     Article  doi:10.1186/s12920-022-01215-x       en
# 8     Article  doi:10.1186/s13619-022-00114-x       en
# 9     Article  doi:10.1186/s43042-022-00286-w       en
#
#                                                  url  \
# 0  [{'format': 'html', 'platform': 'web', 'value'...
# 1  [{'format': 'html', 'platform': 'web', 'value'...
# 2  [{'format': 'html', 'platform': 'web', 'value'...
# 3  [{'format': 'html', 'platform': 'web', 'value'...
# 4  [{'format': 'html', 'platform': 'web', 'value'...
# ...

# %%
print(df.iloc[1])
# Out:
# contentType                                                    Article
# identifier                              doi:10.1186/s12874-022-01567-z
# language                                                            en
# url                  [{'format': 'html', 'platform': 'web', 'value'...
# title                KMSubtraction: reconstruction of unreported su...
# creators             [{'creator': 'Zhao, Joseph J.'}, {'creator': '...
# publicationName                       BMC Medical Research Methodology
# openaccess                                                        true
# doi                                         10.1186/s12874-022-01567-z
# publisher                                               BioMed Central
# publisherName                                           BioMed Central
# publicationDate                                             2022-04-03
# publicationType                                                Journal
# issn
# ...

# %%
import json
from bson import ObjectId  # Import ObjectId from bson module

# Index of the row you want to convert
index = 1

# Retrieve data from MongoDB collection with '_id' field included
data_from_mongodb = list(collection.find({}, {'_id': 1}))

# Convert data to DataFrame
df = pd.DataFrame(data_from_mongodb)

# Get the row as a dictionary
row_data = df.iloc[index].to_dict()

# Retrieve the ObjectId from the '_id' column
object_id = row_data['_id']

# Convert the ObjectId to a string and wrap it in the correct format
row_data['_id'] = {"$oid": str(object_id)}

# Convert the dictionary to JSON-like format
json_data = json.dumps(row_data)

# Print the JSON-like format
print(json_data)
# Out:
# ---------------------------------------------------------------
# ServerSelectionTimeoutError   Traceback (most recent call last)
# Cell In[49], line 8
#       5 index = 1
#       7 # Retrieve data from MongoDB collection with '_id' field included
# ----> 8 data_from_mongodb = list(collection.find({}, {'_id': 1}))
#      10 # Convert data to DataFrame
#      11 df = pd.DataFrame(data_from_mongodb)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymongo\cursor.py:1248, in Cursor.next(self)
#    1246 if self.__empty:
#    1247     raise StopIteration
# -> 1248 if len(self.__data) or self._refresh():
#    1249     return self.__data.popleft()
#    1250 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymongo\cursor.py:1139, in Cursor._refresh(self)
#    1136     return len(self.__data)
#    1138 if not self.__session:
# -> 1139     self.__session = self.__collection.database.client._ensure_session()
#    1141 if self.__id is None:  # Query
# ...

# %%
# Replace '<password>' with your actual password
password = '<trevor_pubnexus>'
uri = f"mongodb+srv://trevsauer:{password}@cluster0.4kmvnav.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Connect to the MongoDB cluster
client = MongoClient(uri)

# Access the database and collection
db = client['capstone']
collection = db['biomed_data']

# %%
# Retrieve data from MongoDB collection
data_from_mongodb = list(collection.find())

# Convert data to DataFrame
df = pd.DataFrame(data_from_mongodb)
df
# Out:
# ---------------------------------------------------------------
# ServerSelectionTimeoutError   Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Retrieve data from MongoDB collection
# ----> 2 data_from_mongodb = list(collection.find())
#       4 # Convert data to DataFrame
#       5 df = pd.DataFrame(data_from_mongodb)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymongo\cursor.py:1248, in Cursor.next(self)
#    1246 if self.__empty:
#    1247     raise StopIteration
# -> 1248 if len(self.__data) or self._refresh():
#    1249     return self.__data.popleft()
#    1250 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymongo\cursor.py:1139, in Cursor._refresh(self)
#    1136     return len(self.__data)
#    1138 if not self.__session:
# -> 1139     self.__session = self.__collection.database.client._ensure_session()
#    1141 if self.__id is None:  # Query
#    1142     if (self.__min or self.__max) and not self.__hint:
#
# ...

# %%
# Insert the data into the collection
collection.insert_many(data)
# Out:
# ---------------------------------------------------------------
# ServerSelectionTimeoutError   Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Insert the data into the collection
# ----> 2 collection.insert_many(data)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymongo\collection.py:714, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     712 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     713 blk.ops = [doc for doc in gen()]
# --> 714 blk.execute(write_concern, session=session)
#     715 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ...

# %%
import ssl
# Connect to MongoDB with SSL verification disabled
client = MongoClient('mongodb+srv://trevsauer:<trevor_pubnexus>@cluster0.4kmvnav.mongodb.net/capstone?retryWrites=true&w=majority&appName=Cluster0',
                     ssl_cert_reqs=ssl.CERT_NONE)

db = client['capstone']
collection = db['biomed_data']

# Assuming 'df' is your DataFrame
data = df.to_dict(orient='records')

# Push DataFrame to MongoDB collection
collection.insert_many(data)
# Out:
# ---------------------------------------------------------------
# ConfigurationError            Traceback (most recent call last)
# Cell In[43], line 3
#       1 import ssl
#       2 # Connect to MongoDB with SSL verification disabled
# ----> 3 client = MongoClient('mongodb+srv://trevsauer:<trevor_pubnexus>@cluster0.4kmvnav.mongodb.net/capstone?retryWrites=true&w=majority&appName=Cluster0',
#       4                      ssl_cert_reqs=ssl.CERT_NONE)
#       6 db = client['capstone']
#       7 collection = db['biomed_data']
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymongo\mongo_client.py:771, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     768 keyword_opts = _handle_option_deprecations(keyword_opts)
#     769 # Validate kwarg options.
#     770 keyword_opts = common._CaseInsensitiveDictionary(
# --> 771     dict(common.validate(keyword_opts.cased_key(k), v) for k, v in keyword_opts.items())
#     772 )
# ...
